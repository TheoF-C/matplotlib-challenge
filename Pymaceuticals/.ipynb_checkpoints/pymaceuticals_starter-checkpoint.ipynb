# %%
# Dependencies and Setup
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# Hide warning messages in notebook
import warnings
warnings.filterwarnings('ignore')

# File to Load (Remember to Change These)
mouse_drug_data_to_load = "mouse_drug_data.csv"
clinical_trial_data_to_load = "clinicaltrial_data.csv"

# Read the Mouse and Drug Data and the Clinical Trial Data
trial_mouse_data = pd.read_csv(mouse_drug_data_to_load)
trial_drug_data = pd.read_csv(clinical_trial_data_to_load)

# Combine the data into a single dataset
trial_mouse_data = trial_mouse_data.merge(trial_drug_data, on='Mouse ID')

# Display the data table for preview
display(trial_mouse_data.head(5))
# Out:
#   Mouse ID      Drug  Timepoint  Tumor Volume (mm3)  Metastatic Sites
# 0     f234  Stelasyn          0           45.000000                 0
# 1     f234  Stelasyn          5           47.313491                 0
# 2     f234  Stelasyn         10           47.904324                 0
# 3     f234  Stelasyn         15           48.735197                 1
# 4     f234  Stelasyn         20           51.112713                 2

# %% [markdown]
# ## Tumor Response to Treatment

# %%
tumor_group = trial_mouse_data.groupby(['Drug', 'Timepoint'])['Tumor Volume (mm3)']

# Store the Mean Tumor Volume Data Grouped by Drug and Timepoint
tumor_mean = tumor_group.mean()

# Convert to DataFrame
tumor_mean = tumor_mean.to_frame()

# Preview DataFrame
tumor_mean.head()
# Out:
#                      Tumor Volume (mm3)
# Drug      Timepoint
# Capomulin 0                   45.000000
#           5                   44.266086
#           10                  43.084291
#           15                  42.064317
#           20                  40.716325

# %%
# Store the Standard Error of Tumor Volumes Grouped by Drug and Timepoint
tumor_sem = tumor_group.sem()

# Convert to DataFrame
tumor_sem = tumor_sem.to_frame()

# Preview DataFrame
tumor_sem.head()
# Out:
#                      Tumor Volume (mm3)
# Drug      Timepoint
# Capomulin 0                    0.000000
#           5                    0.448593
#           10                   0.702684
#           15                   0.838617
#           20                   0.909731

# %%
# Reformating data frame
tumor_mean = tumor_mean.unstack(level=0)
tumor_sem = tumor_sem.unstack(level=0)

# Displaying data frame
display(tumor_mean.head(5))
# Out:
#           Tumor Volume (mm3)                                              \
# Drug               Capomulin   Ceftamin  Infubinol   Ketapril   Naftisol
# Timepoint
# 0                  45.000000  45.000000  45.000000  45.000000  45.000000
# 5                  44.266086  46.503051  47.062001  47.389175  46.796098
# 10                 43.084291  48.285125  49.403909  49.582269  48.694210
# 15                 42.064317  50.094055  51.296397  52.399974  50.933018
# 20                 40.716325  52.157049  53.197691  54.920935  53.644087
#
#
# Drug         Placebo   Propriva   Ramicane   Stelasyn  Zoniferol
# Timepoint
# 0          45.000000  45.000000  45.000000  45.000000  45.000000
# 5          47.125589  47.248967  43.944859  47.527452  46.851818
# 10         49.423329  49.101541  42.531957  49.463844  48.689881
# 15         51.359742  51.067318  41.495061  51.529409  50.779059
# 20         54.364417  53.346737  40.238325  54.067395  53.170334

# %%
# Generate the Plot (with Error Bars)
for drug in tumor_mean.columns:
    plt.errorbar(tumor_mean.index, tumor_mean[drug], yerr=tumor_sem[drug], marker="d", linewidth=0.70)

# Labeling plot
plt.title('Tumor Response to Treatment')
plt.ylabel('Tumor Volume (mm3)')
plt.xlabel('Time (days)')
plt.legend([drug[1] for drug in tumor_mean.columns], loc='upper left', prop={'size': 7.5})

# Save the Figure
plt.savefig('TumorResponse.png')

# %%
# Show the Figure
plt.show()

# %% [markdown]
# ![Tumor Response to Treatment](../Images/treatment.png)

# %% [markdown]
# ## Metastatic Response to Treatment

# %%
# Store metastatic site data grouped by Drug and Timepoint
metastatic_group = trial_mouse_data.groupby(['Drug', 'Timepoint'])['Metastatic Sites']

# Store the Mean Met. Site Data Grouped by Drug and Timepoint 
metastatic_mean = metastatic_group.mean()

# Convert to DataFrame
metastatic_mean = metastatic_mean.to_frame()

# Preview DataFrame
metastatic_mean.head()
# Out:
#                      Metastatic Sites
# Drug      Timepoint
# Capomulin 0                  0.000000
#           5                  0.160000
#           10                 0.320000
#           15                 0.375000
#           20                 0.652174

# %%
# Store the Standard Error associated with Met. Sites Grouped by Drug and Timepoint 
metastatic_error = metastatic_group.sem()

# Convert to DataFrame
metastatic_error = metastatic_error.to_frame()

# Preview DataFrame
metastatic_error.head()
# Out:
#                      Metastatic Sites
# Drug      Timepoint
# Capomulin 0                  0.000000
#           5                  0.074833
#           10                 0.125433
#           15                 0.132048
#           20                 0.161621

# %%
# Minor Data Munging to Re-Format the Data Frames
metastatic_mean = metastatic_mean.unstack(level=0)
metastatic_error = metastatic_error.unstack(level=0)

# Preview that Reformatting worked
display(metastatic_mean.head(5))
# Out:
#           Metastatic Sites                                                    \
# Drug             Capomulin  Ceftamin Infubinol  Ketapril  Naftisol   Placebo
# Timepoint
# 0                 0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 5                 0.160000  0.380952  0.280000  0.304348  0.260870  0.375000
# 10                0.320000  0.600000  0.666667  0.590909  0.523810  0.833333
# 15                0.375000  0.789474  0.904762  0.842105  0.857143  1.250000
# 20                0.652174  1.111111  1.050000  1.210526  1.150000  1.526316
#
#
# Drug       Propriva  Ramicane  Stelasyn Zoniferol
# Timepoint
# 0          0.000000  0.000000  0.000000  0.000000
# 5          0.320000  0.120000  0.240000  0.166667
# 10         0.565217  0.250000  0.478261  0.500000
# 15         0.764706  0.333333  0.782609  0.809524
# 20         1.000000  0.347826  0.952381  1.294118

# %%
# Generate the Plot (with Error Bars)
for drug in metastatic_mean.columns:
    plt.errorbar(metastatic_mean.index, metastatic_mean[drug], yerr=metastatic_error[drug], marker="d", linewidth=0.70)

# Labeling plot
plt.title('Metastatic Sites over Treatment')
plt.ylabel('Metastatic sites')
plt.xlabel('Time (days)')
plt.legend([drug[1] for drug in metastatic_mean.columns], loc='upper left', prop={'size': 7.5})

# Save the Figure
plt.savefig('MetastaticResponse.png')

# Show the Figure
plt.show()

# %% [markdown]
# ![Metastatic Spread During Treatment](../Images/spread.png)

# %% [markdown]
# ## Survival Rates

# %%
# Store the Count of Mice Grouped by Drug and Timepoint (W can pass any metric)
survival_group = trial_mouse_data.groupby(['Drug', 'Timepoint'])['Mouse ID'].count()

# Convert to DataFrame
survival_group = survival_group.to_frame()

# Preview DataFrame
survival_group.head()
# Out:
#                      Mouse ID
# Drug      Timepoint
# Capomulin 0                25
#           5                25
#           10               25
#           15               24
#           20               23

# %%
# Minor Data Munging to Re-Format the Data Frames
survival_group = survival_group.unstack(level=0)
survival_group.columns = survival_group.columns.droplevel(0)

# Preview the Data Frame
survival_group.head(5)
# Out:
# Drug       Capomulin  Ceftamin  Infubinol  Ketapril  Naftisol  Placebo  \
# Timepoint
# 0                 25        25         25        25        25       25
# 5                 25        21         25        23        23       24
# 10                25        20         21        22        21       24
# 15                24        19         21        19        21       20
# 20                23        18         20        19        20       19
#
# Drug       Propriva  Ramicane  Stelasyn  Zoniferol
# Timepoint
# 0                26        25        26         25
# 5                25        25        25         24
# 10               23        24        23         22
# 15               17        24        23         21
# 20               17        23        21         17

# %%
# Normalize data frame
for c in survival_group.columns:
    survival_group[c] *= 100 / survival_group[c][0]
    
# Generate the Plot (Accounting for percentages)
for drug in survival_group.columns:
    plt.errorbar(survival_group.index, survival_group[drug], marker="d", linewidth=0.70)

# Labeling plot
plt.title('Survival Rate over Treatment')
plt.ylabel('Survival rate (%)')
plt.xlabel('Time (days)')
plt.legend(survival_group.columns, loc='lower left', prop={'size': 7.5})

# Save the Figure
plt.savefig('SurvivalRate.png')

# Show the Figure
plt.show()

# %% [markdown]
# ![Metastatic Spread During Treatment](../Images/survival.png)

# %% [markdown]
# ## Summary Bar Graph

# %%
# Calculate the percent changes for each drug
tumor_change_volume = 100 * (tumor_mean.iloc[-1] - tumor_mean.iloc[0]) / tumor_mean.iloc[0]
tumor_change_error = 100 * (tumor_sem.iloc[-1] - tumor_sem.iloc[0]) / tumor_sem.iloc[0]

# Display the data to confirm
display(tumor_change_volume)
# Out:
#                     Drug
# Tumor Volume (mm3)  Capomulin   -19.475303
#                     Ceftamin     42.516492
#                     Infubinol    46.123472
#                     Ketapril     57.028795
#                     Naftisol     53.923347
#                     Placebo      51.297960
#                     Propriva     47.241175
#                     Ramicane    -22.320900
#                     Stelasyn     52.085134
#                     Zoniferol    46.579751
# dtype: float64

# %%
# Store all Relevant Percent Changes into a Tuple
tumor_change_volume = tumor_change_volume.sort_values(ascending=True)

# Splice the data between passing and failing drugs
fig, ax = plt.subplots()
values = list(range(len(tumor_change_volume)))
rectsPass = ax.bar(values[0:2], tumor_change_volume[0:2], color='green')
rectsFail = ax.bar(values[2:], tumor_change_volume[2:], color='red')

# Orient widths. Add labels, tick marks, etc.
ax.set_xticks(list(range(10)))

labels = pd.DataFrame(tumor_change_volume).droplevel(0).index
ax.set_xticklabels(labels, rotation = 45)

# Use functions to label the percentages of changes
def autolabelGreen(rects):
    # attach some text labels
    for rect in rects:
        height = rect.get_height()
        ax.text(rect.get_x() + rect.get_width()/2., 1.05*height,
                '%d' % int(height),
                ha='center', va='bottom')

        
def autolabelRed(rects):
    # attach some text labels
    for rect in rects:
        height = rect.get_height()
        ax.text(rect.get_x() + rect.get_width()/2., 1.05*height,
                '%d' % int(height),
                ha='center', va='top')

# Call functions to implement the function calls
autolabelGreen(rectsPass)
autolabelRed(rectsFail)

# Save the Figure


# Show the Figure
fig.show()
# Out:
#                    0
# Drug
# Ramicane  -22.320900
# Capomulin -19.475303
# Ceftamin   42.516492
# Infubinol  46.123472
# Zoniferol  46.579751
# Propriva   47.241175
# Placebo    51.297960
# Stelasyn   52.085134
# Naftisol   53.923347
# Ketapril   57.028795

# %% [markdown]
# ![Metastatic Spread During Treatment](../Images/change.png)
